# %%
import tushare as ts
import pandas as pd
from pandas import DataFrame,Series
import pyecharts as ec

# %%
from pyecharts.charts import Line
from pyecharts.globals import CurrentConfig, NotebookType
import pyecharts.options as opts

# %%
#bar = Bar()
#bar.add_xaxis(["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"])
#bar.add_yaxis("商家A", [5, 20, 36, 10, 75, 90])
# render 会生成本地 HTML 文件，默认会在当前目录生成 render.html 文件
# 也可以传入路径参数，如 bar.render("mycharts.html")
#bar.render_notebook()

# %%
#init
tok = "6e600273078e0ef22636298e3bed37f38c577d8829ba250731368234"
pro = ts.pro_api(tok)

# %%
df = pro.index_daily(ts_code='000821.CSI', start_date='20120720', end_date='20191231')

# %%
df1 = pro.index_daily(ts_code='000822.CSI', start_date='2012720', end_date='20191231')

# %%
df = df.reindex(range(len(df.index) - 1, -1, -1))
df1 = df1.reindex(range(len(df1.index) - 1, -1, -1))

# %%
c= Line()

c.add_xaxis(df['trade_date']
           )
c.add_yaxis("000821.CSI", df['close'].values,
            label_opts = opts.LabelOpts(is_show=False), 
            is_smooth = False,
           )
c.add_yaxis("000822.CSI", df1['close'].values,
            label_opts = opts.LabelOpts(is_show=False), 
            is_smooth = False,
           )


#c.set_series_opts(label_opts=opts.LabelOpts(is_show=True))
c.set_global_opts(yaxis_opts=opts.AxisOpts(name = "y",
                                           is_show = True, 
                                           position = "top",
                                           #split_number = 10,
                                           min_ = 2000,
                                           ),
                 xaxis_opts = opts.AxisOpts(name = "20180101 - 20191231",
                                            type_ = "category",
                                            is_show = True,
                                            name_location = "center",
                                            name_gap = 30,
                                            axispointer_opts = opts.AxisPointerOpts(is_show = True, type_="line"),
                                            #axispointer_opts = {"is_show":True, "type_":"shadow"},
                                            min_interval = 1
                                            
                 )
                 )

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="b7679ba1295f4124b5b42ba215fac972" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_b7679ba1295f4124b5b42ba215fac972 = echarts.init(
#                     document.getElementById('b7679ba1295f4124b5b42ba215fac972'), 'white', {renderer: 'canvas'});
#                 var option_b7679ba1295f4124b5b42ba215fac972 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
# Out:
#        ts_code trade_date      close       open       high        low  \
# 0    000001.SH   20191231  3050.1240  3036.3858  3051.6770  3030.5122
# 1    000001.SH   20191230  3040.0239  2998.1689  3041.3969  2983.3436
# 2    000001.SH   20191227  3005.0355  3006.8517  3036.1127  3003.6309
# 3    000001.SH   20191226  3007.3546  2981.2485  3007.3546  2980.3966
# 4    000001.SH   20191225  2981.8805  2980.4276  2988.2924  2970.6572
# ..         ...        ...        ...        ...        ...        ...
# 482  000001.SH   20180108  3409.4795  3391.5528  3412.7307  3384.5591
# 483  000001.SH   20180105  3391.7501  3386.4640  3402.0694  3380.2450
# 484  000001.SH   20180104  3385.7102  3371.0000  3392.8264  3365.2954
# 485  000001.SH   20180103  3369.1084  3347.7428  3379.9152  3345.2887
# 486  000001.SH   20180102  3348.3259  3314.0307  3349.0530  3314.0307
#
#      pre_close   change  pct_chg          vol       amount
# 0    3040.0239  10.1001   0.3322  217429022.0  226763991.3
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-100-72f4d06989dd> in <module>
# ----> 1 df2 = pro.index_weight(index_code='399300.SZ', start_date='20180901', end_date='20180930')
#
# ~\Anaconda3\lib\site-packages\tushare\pro\client.py in query(self, api_name, fields, **kwargs)
#      41         result = json.loads(res.text)
#      42         if result['code'] != 0:
# ---> 43             raise Exception(result['msg'])
#      44         data = result['data']
#      45         columns = data['fields']
#
# Exception: 抱歉，您没有访问该接口的权限，权限的具体详情访问：https://tushare.pro/document/1?doc_id=108。
