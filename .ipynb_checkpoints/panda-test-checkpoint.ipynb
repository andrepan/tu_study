# %%
import pandas as pd
from pandas import DataFrame,Series
import tushare as ts

# %%
ts.set_token("6e600273078e0ef22636298e3bed37f38c577d8829ba250731368234")
pro = ts.pro_api()
df = pro.trade_cal(exchange='', start_date='20180901', end_date='20181001', fields='exchange,cal_date,is_open,pretrade_date', is_open='0')

# %%
pro = ts.pro_api()
df = pro.index_basic(market='SSE')
# Out:
#        ts_code         name market publisher category base_date  base_point  \
# 0    000001.SH         上证综指    SSE      中证公司     综合指数  19901219      100.00
# 1    000002.SH         上证A指    SSE      中证公司     综合指数  19901219      100.00
# 2    000003.SH         上证B指    SSE      中证公司     综合指数  19920221      100.00
# 3    000004.SH      上证工业类指数    SSE      中证公司     综合指数  19930430     1358.78
# 4    000005.SH      上证商业类指数    SSE      中证公司     综合指数  19930430     1358.78
# ..         ...          ...    ...       ...      ...       ...         ...
# 585  n50110.SH    上证超长国债(利)    SSE       上交所     债券指数  20081231      100.00
# 586  n50113.SH  沪质中高债3-5(利)    SSE       上交所     债券指数  20081231      100.00
# 587  n50117.SH     上证绿色债(利)    SSE       上交所     债券指数  20161230      100.00
# 588  n50118.SH   上证绿色公司债(利)    SSE       上交所     债券指数  20161230      100.00
# 589  T00901.SH      小康指数(旧)    SSE      中证公司     主题指数  20051230     1000.00
#
#     list_date
# 0    19910715
# 1    19920221
# 2    19920221
# 3    19930503
# 4    19930503
# ..        ...
# 585  20161114
# 586  20170223
# 587  20170619
# 588  20170619
# 589  20060109
#
# [590 rows x 8 columns]

# %%
for i in df.index:
    if '300' in df.loc[i]['name']: #print(i['name'])
        print(df.loc[i])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-117-e985bbe442fb> in <module>
#       1 for i in df.index:
# ----> 2     print(i['name'])
#       3         #print(df.loc[i])
#
# TypeError: 'int' object is not subscriptable

# %%
df.loc[0]
# Out:
# ts_code       000001.SH
# name               上证综指
# publisher          中证公司
# category           综合指数
# base_date      19901219
# base_point          100
# list_date      19910715
# Name: 0, dtype: object
